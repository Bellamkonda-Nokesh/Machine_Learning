# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# Generate quadratic data with some noise
np.random.seed(0)
X = np.linspace(-3, 3, 20).reshape(-1, 1)  # Corrected np.linspace
y = X**2 + np.random.normal(0, 1, X.shape)  # Quadratic function with noise

# Train two models: Linear (Underfitting) and Polynomial (Overfitting)
linear_model = LinearRegression()
poly_features = PolynomialFeatures(degree=5)
poly_model = LinearRegression()

# Fit the models
linear_model.fit(X, y)
X_poly = poly_features.fit_transform(X)
poly_model.fit(X_poly, y)

# Predictions
X_test = np.linspace(-3, 3, 100).reshape(-1, 1)  # Corrected np.linspace
y_linear_pred = linear_model.predict(X_test)
y_poly_pred = poly_model.predict(poly_features.transform(X_test))

# Plot results
plt.scatter(X, y, color="black", label="Actual Data")
plt.plot(X_test, y_linear_pred, label="Underfitting (Linear)", color="blue")
plt.plot(X_test, y_poly_pred, label="Overfitting (Polynomial Degree 5)", color="red")
plt.legend()
plt.title("Underfitting vs Overfitting (Quadratic Data)")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
np.random.seed(0)
X = np.linspace(-3, 3, 20).reshape(-1, 1)
y = X**2 + np.random.normal(0, 1, X.shape)
linear_model = LinearRegression().fit(X, y)
poly_model = LinearRegression().fit(PolynomialFeatures(degree=5).fit_transform(X), y)
X_test = np.linspace(-3, 3, 100).reshape(-1, 1)
y_linear_pred = linear_model.predict(X_test)
y_poly_pred = poly_model.predict(PolynomialFeatures(degree=5).fit_transform(X_test))
plt.scatter(X, y, color="black", label="Actual Data")
plt.plot(X_test, y_linear_pred, label="Underfitting (Linear)", color="blue")
plt.plot(X_test, y_poly_pred, label="Overfitting (Polynomial Degree 5)", color="red")
plt.legend()
plt.title("Underfitting vs Overfitting (Quadratic Data)")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
np.random.seed(0)
X = np.linspace(0,10,10).reshape(-1,1)
Y = X**2 + np.random.normal(0, 5, size = X.shape)

#fit models
lin_reg = LinearRegression().fit(X,Y)
poly2 = LinearRegression().fit(PolynomialFeatures(3).fit_transform(X),Y)
poly8 = LinearRegression().fit(PolynomialFeatures(8).fit_transform(X),Y)

#Predictions
Y_pred_linear = lin_reg.predict(X)
Y_pred_poly2 = poly2.predict(PolynomialFeatures(3).fit_transform(X))
Y_pred_poly8 = poly8.predict(PolynomialFeatures(8).fit_transform(X))

#plot
plt.scatter(X,Y, color = 'black')
plt.plot(X,Y_pred_linear, label = "Underfit(Linear)")
plt.plot(X,Y_pred_poly2, label = "Good Fit (Quadratic)")
plt.plot(X,Y_pred_poly8, label = "Overfit(8-degree)")
plt.legend()
plt.show()
