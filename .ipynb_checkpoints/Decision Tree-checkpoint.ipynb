# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import matplotlib.pyplot as plt

X=[[25,50000],[30,60000],[35,70000],[40,80000],[45,90000],[50,100000]]
Y=[0,0,1,1,1,1]
model= DecisionTreeClassifier()
model.fit(X,Y)
plt.figure(figsize=(4,3))
tree.plot_tree(model,feature_names=["Age","Salary"],class_names=["No","Yes"],filled=True)
plt.show()
prediction=model.predict([[32,650000]])
print("Prediction:","Yes" if prediction[0]==1 else "No")
# Out:
# Prediction: Yes

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import matplotlib.pyplot as plt
#Sample dataset
X=[[1],[2],[3],[4],[5]]
y=[1,1,0,0,1]
#Train a decision Tree
model=DecisionTreeClassifier(criterion="gini")
model.fit(X,y)
#Visualize the tree
plt.figure(figsize=(3,4))
tree.plot_tree(model,feature_names=["Features"],class_names=["No","Yes"],filled=True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.preprocessing import LabelEncoder

# Load dataset
df = pd.read_csv("drug200.csv")

# Prepare features (X) and target (y)
X = pd.get_dummies(df.drop(columns=["Drug"]))  
y = LabelEncoder().fit_transform(df["Drug"])   

# Train Decision Tree
model = DecisionTreeClassifier()
model.fit(X, y)

# Plot tree
plt.figure(figsize=(8, 6))
plot_tree(model, feature_names=X.columns, filled=True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv("drug200.csv")
print("Dataset Preview:\n", df.head())

le = LabelEncoder()


df['Sex'] = le.fit_transform(df['Sex'])  
df['BP'] = le.fit_transform(df['BP'])  
df['Cholesterol'] = le.fit_transform(df['Cholesterol'])  

X = df[['Age', 'Sex', 'BP', 'Cholesterol', 'Na_to_K']]
Y = df['Drug']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)
dtree = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=42)
dtree.fit(X_train, Y_train)
Y_pred = dtree.predict(X_test)

print("\nAccuracy:", accuracy_score(Y_test, Y_pred))
print("\nConfusion Matrix:\n", confusion_matrix(Y_test, Y_pred))
print("\nDecision Tree Rules:\n", export_text(dtree, feature_names=list(X.columns)))
plt.figure(figsize=(12, 8))
plot_tree(dtree, feature_names=X.columns, class_names=[str(i) for i in set(Y)], filled=True)
plt.show()
# Out:
# Dataset Preview:
#     Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  drugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  drugY
#
# Accuracy: 0.9
#
# Confusion Matrix:
#  [[ 7  0  0  0  0]
#  [ 0  3  0  0  0]
#  [ 0  0  0  6  0]
#  [ 0  0  0 18  0]
#  [ 0  0  0  0 26]]
#
# Decision Tree Rules:
#  |--- Na_to_K <= 14.83
# |   |--- BP <= 0.50
# |   |   |--- Age <= 50.50
# |   |   |   |--- class: drugA
# |   |   |--- Age >  50.50
# |   |   |   |--- class: drugB
# |   |--- BP >  0.50
# |   |   |--- BP <= 1.50
# |   |   |   |--- class: drugX
# |   |   |--- BP >  1.50
# |   |   |   |--- class: drugX
# |--- Na_to_K >  14.83
# |   |--- class: drugY
